# %%
# !pip install langchain-experimental
# Out:
# Requirement already satisfied: langchain-experimental in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (0.0.64)
# Requirement already satisfied: langchain-community<0.3.0,>=0.2.10 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-experimental) (0.2.11)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.27 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-experimental) (0.2.28)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-community<0.3.0,>=0.2.10->langchain-experimental) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-community<0.3.0,>=0.2.10->langchain-experimental) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-community<0.3.0,>=0.2.10->langchain-experimental) (3.10.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-community<0.3.0,>=0.2.10->langchain-experimental) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.12 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-community<0.3.0,>=0.2.10->langchain-experimental) (0.2.12)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-community<0.3.0,>=0.2.10->langchain-experimental) (0.1.98)
# Requirement already satisfied: numpy<2,>=1 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-community<0.3.0,>=0.2.10->langchain-experimental) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-community<0.3.0,>=0.2.10->langchain-experimental) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-community<0.3.0,>=0.2.10->langchain-experimental) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain-experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\jyseo\appdata\roaming\python\python39\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain-experimental) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain-experimental) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\jyseo\appdata\roaming\python\python39\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain-experimental) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.27->langchain-experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langchain<0.3.0,>=0.2.12->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (0.2.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.27->langchain-experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.27->langchain-experimental) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.10->langchain-experimental) (1.0.0)

# %%
# !pip install tabulate
# Out:
# Requirement already satisfied: tabulate in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (0.9.0)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jyseo\appdata\roaming\python\python39\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\jyseo\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (1.40.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\jyseo\appdata\roaming\python\python39\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\jyseo\appdata\roaming\python\python39\site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jyseo\anaconda3\envs\openai39\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: colorama in c:\users\jyseo\appdata\roaming\python\python39\site-packages (from tqdm>4->openai) (0.4.6)

# %%
import pandas as pd #파이썬 언어로 작성된 데이터를 분석 및 조작하기 위한 라이브러리

#csv 파일을 데이터프레임으로 가져오기
df = pd.read_csv('d:/data/booksv_02.csv') #booksv_02.csv 파일이 위치한 경로 지정
df.head()
# Out:
#             title subtitle                          authors  \
# 0          Gilead      NaN               Marilynne Robinson
# 1    Spider's Web  A Novel  Charles Osborne;Agatha Christie
# 2    The One Tree      NaN             Stephen R. Donaldson
# 3  Rage of angels      NaN                   Sidney Sheldon
# 4  The Four Loves      NaN              Clive Staples Lewis
#
#                       categories  \
# 0                        Fiction
# 1  Detective and mystery stories
# 2               American fiction
# 3                        Fiction
# 4                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
# 3  http://books.google.com/books/content?id=FKo2T...
# 4  http://books.google.com/books/content?id=XhQ5X...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...            2004
# 1  A new 'Christie for Christmas' -- a full-lengt...            2000
# 2  Volume Two of Stephen Donaldson's acclaimed se...            1982
# 3  A memorable, mesmerizing heroine Jennifer -- b...            1993
# 4  Lewis' work on the nature of love divides love...            2002
#
#    average_rating  num_pages  ratings_count
# 0            3.85        247            361
# 1            3.83        241           5164
# 2            3.97        479            172
# 3            3.93        512          29532
# 4            4.15        170          33684

# %%
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
from langchain.chat_models import ChatOpenAI
from langchain.agents.agent_types import AgentType
import os
os.environ["OPENAI_API_KEY"] = "sk" #openai 키 입력

#에이전트 생성
agent = create_pandas_dataframe_agent(
    ChatOpenAI(temperature=0, model='gpt-4o'),  #gpt-3.5-turbo 사용
    df,             #데이터가 담긴 곳
    verbose=False,  #추론 과정을 출력하지 않음
    agent_type=AgentType.OPENAI_FUNCTIONS, 
    allow_dangerous_code=True,
)
# Out:
# C:\Users\JYSEO\anaconda3\envs\openai39\lib\site-packages\langchain_core\_api\deprecation.py:139: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
agent.run('어떤 제품의 ratings_count가 제일 높아?')
# Out:
# C:\Users\JYSEO\anaconda3\envs\openai39\lib\site-packages\langchain_core\_api\deprecation.py:139: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# '`One Hundred Years of Solitude`라는 책이 가장 높은 ratings_count를 가지고 있습니다. 이 책의 ratings_count는 547,207입니다. \n\n- **Title**: One Hundred Years of Solitude\n- **Authors**: Gabriel Garcia Marquez\n- **Categories**: Fiction\n- **Published Year**: 2003\n- **Average Rating**: 4.06\n- **Number of Pages**: 417'

# %%
agent.run('가장 최근에 출간된 책은?')
# Out:
# "가장 최근에 출간된 책들은 모두 2007년에 출간되었습니다. 그 중 일부는 다음과 같습니다:\n\n1. **The Yiddish Policemen's Union** by Michael Chabon\n2. **The Kindness of Strangers** by Katrina Kittle\n3. **The Dead Beat** by Marilyn Johnson\n4. **A False Mirror** by Charles Todd\n5. **For a Few Demons More** by Kim Harrison\n\n이 외에도 2007년에 출간된 책들이 더 있습니다."
